# %% [markdown]
# # Your Friend: Mekan Jumayev
#
# 🔴 **Instagram**: _@jumaevmekan_  :)

# %% [markdown]
# # Introduction to pandas

# %% [raw]
# Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks.

# %% [raw]
# Pandas makes it simple to do many of the time consuming, repetitive tasks associated with working with data, including:
#
# - Data cleansing
# - Data fill
# - Data normalization
# - Merges and joins
# - Data visualization!
# - Statistical analysis
# - Data inspection
# - Loading and saving data
# - And much more

# %% [raw]
# Pandas 2 shekilde data saklaya:
# - Series
# - DataFrame

# %%
# displaying image in notebook
from IPython.display import Image
Image(filename='ps.png')

# %% [markdown]
# # Installation

# %%
# install pandas library in python
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Series

# %%
# import libraries 
import pandas as pd
import numpy as np
import re

# %%
# create empty pandas Series Note: empty Series should be 'object' datatype otherwise default 'float64'
empty = pd.Series(dtype='object')

# %%
# print empty Series
empty
# Out:
# Series([], dtype: float64)

# %%
# create Series with 10 value
ten = pd.Series(10)
ten
# Out:
# 0    10
# dtype: int64

# %%
# create Series with list of values
names = ["mekan", "ali", "serdar"]
i = ["a", "b", "c"]
names_Series = pd.Series(data=names, index=i)

# %%
names_Series

# %% [markdown]
# # DataFrame

# %%
from IPython.display import Image
Image(filename='dataframe.png')

# %%
# pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)

# %%
# create empty Dataframe
empty = pd.DataFrame()

# %%
empty
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# prepare data for DF
names = ["Mekan", "Ali", "Eziz"]
age = [21, 22, 23]
marks = [83.5, 75.1, 87.0]
index = ["Std1", "Std2", "Std3"]

datas = {
    "Names": names,
    "Age": age,
    "Marks": marks
}

# create a Dataframe with the prepared datas
students = pd.DataFrame(data=datas, index=index)

students
# Out:
#       Names  Age  Marks
# Std1  Mekan   21   83.5
# Std2    Ali   22   75.1
# Std3   Eziz   23   87.0

# %% [markdown]
# # Load Data

# %% [markdown]
# - EXCEL
# - CSV
# - TXT
# - JSON
# - HTML
# - PICKLE
# - SQL
# - XML

# %%
# reading excel file
excel = pd.read_excel("pokemon_data.xlsx")

# %%
# reading csv file
csv = pd.read_csv("pokemon_data.csv")

# %%
# reading txt file
txt = pd.read_csv("pokemon_data.txt", delimiter="\t")

# %% [markdown]
# # DataFrame Attributes

# %% [markdown]
# - df.index
# - df.columns
# - df.dtypes
# - df.values
# - df.empty
# - df.size
# - df.shape
# - df.describe()

# %%
# get dataframe's index range
excel.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
# loop in list of columns of Dataframe
for i in excel.columns:
    print(i)
# Out:
# #
# Name
# Type 1
# Type 2
# HP
# Attack
# Defense
# Sp. Atk
# Sp. Def
# Speed
# Generation
# Legendary

# %%
# Display each column's datatype
excel.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# read the dataframe as an array/list
excel.values
# Out:
# array([[1, 'Bulbasaur', 'Grass', ..., 45, 1, False],
#        [2, 'Ivysaur', 'Grass', ..., 60, 1, False],
#        [3, 'Venusaur', 'Grass', ..., 80, 1, False],
#        ...,
#        [720, 'HoopaHoopa Confined', 'Psychic', ..., 70, 6, True],
#        [720, 'HoopaHoopa Unbound', 'Psychic', ..., 80, 6, True],
#        [721, 'Volcanion', 'Fire', ..., 70, 6, True]], dtype=object)

# %%
# is dataframe is empty or not, returns True or False
excel.empty
# Out:
# False

# %%
# #rows * #columns
excel.size
# Out:
# 9600

# %%
excel.shape # (# rows, # cols)
# Out:
# (800, 12)

# %%
# display statistics values of dataframe
excel.describe()

# %% [markdown]
# # DataFrame Selection

# %% [markdown]
# - df.head()
# - df.tail()
# - df.at[row_no, col_name]
# - df.iat[row_no, col_index]
# - df.get()
# - df[col_name]
# - df.loc[start_row, end_row, [col1, col2..]]
# - df.iloc[start_row:end_row, start_col_index, end_col_index]

# %%
# get first 10 rows
excel.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# get last 10 rows
excel.tail(10)

# %%
# get the cell value in column 'Attack' and in 792 row
excel.at[792, "Attack"]
# Out:
# 131

# %%
# get the cell value in column index at 5 and in 792 row
excel.iat[792, 5]
# Out:
# 131

# %%
# get two columns
excel.get(["Name", "Attack"])

# %%
# get two columns
excel[["Name", "Attack"]]

# %%
# get two columns values at rows between 10 and 100
excel.loc[10:100, ["Name", "Attack"]]

# %%
# get two columns values at rows between 10 and 100
excel.iloc[10:100, 1:3]

# %% [markdown]
# # DataFrame Filtering

# %%
# select * from df where Type1 = Grass and Attack > 70
excel[(excel["Type 1"] == "Grass") & (excel["Attack"] > 70)]

# %%
# select * from df where Name like '%Mega%'
excel[excel["Name"].str.contains("Mega")]

# %%
# select * from df where Name not like '%Mega%'
excel[~excel["Name"].str.contains("Mega")]

# %%
# select * from df where Name like '%Fire%' or Name like '%Grass%'
excel[excel["Type 1"].str.contains('Fire|Grass', regex=True)]

# %%
# select * from df where Name like '%fire%' or Name like '%grass%'  Note: case insensitive
excel[excel["Type 1"].str.contains('fire|grass', flags=re.I, regex=True)]

# %%
# select * from df where Name like 'pi%'
excel[excel["Name"].str.contains('^pi[a-z]*', flags=re.I, regex=True)]

# %% [markdown]
# # DataFrame Modification

# %% [markdown]
# - add/remove rows and columns
# - drop column
# - rename column
# - update value
# - dealing with null values
#     - .notna()
#     - .isnull()
#     - .notnull()
#     - .dropna()
#     - .fillna()
#     - .replace(np.nan, "")
# - drop duplicates

# %%
# add new column with value 1
excel["New"] = 1

# %%
# add new calculated column
power = excel["Attack"] * excel["Defense"] * excel["Speed"]
excel["Power"] = power

# %%
# add new column to 4 column index: example: col0, col1, col2, col3, new_col, col...
excel.insert(loc=4, column="Power2", value=power)

# %%
# rename column
excel.rename(columns={"Power2": "Power3"}, inplace=True)

# %%
# remove columns
excel.drop(columns={"Power", "Power3"}, inplace=True)

# %% [markdown]
# # Add/Remove Rows

# %%
datas = [
    {
    "#": 723,
    "Name": "Test",
    "Type 1": "Type test",
    "Type 2": "Type 2 test",
    "HP": 85,
    "Attack": 100,
    "Defense": 100,
    "Sp. Atk": 90,
    "Sp. Def": 80,
    "Speed": 70,
    "Generation": 7,
    "Legendary": True
    },
    {
    "#": 724,
    "Name": "Test",
    "Type 1": "Type test",
    "Type 2": "Type 2 test",
    "HP": 85,
    "Attack": 100,
    "Defense": 100,
    "Sp. Atk": 90,
    "Sp. Def": 80,
    "Speed": 70,
    "Generation": 7,
    "Legendary": True
    }
    
]

excel = excel.append(datas, ignore_index=True)

# %%
# add new row to index 2
excel.loc[2] = [111, "Name1", "type1 test", "type2 test", 44, 44, 45, 45, 46, 23, 4, False]

# %%
# add new row between 2 and 3
excel.loc[2.5] = [112, "Name1", "type1 test", "type2 test", 44, 44, 45, 45, 46, 23, 4, False]

# %%
# sort by index and then reset index it will start from 0 again
excel = excel.sort_index().reset_index(drop=True)

# %%
# delete row by index
excel.drop(802, inplace=True)

# %% [markdown]
# # Updating values

# %%
# update Type 1 column value (newValue, oldValue)
excel["Type 1"].replace("Grass new", "Grass", inplace=True)

# %%
# Update multiple column value conditionally
excel.loc[(excel["Type 1"] == "Grass") & (excel["Attack"] > 50) & (excel["Speed"] > 50), ["Legendary", "Generation"]] = [True, 100]

# %% [markdown]
# # Sorting Values

# %%
# sort rows
excel.sort_values(["Generation", "Name"], ascending=[True, False])

# %% [markdown]
# # Duplicate Values

# %%
# drop duplicates
excel.drop_duplicates(subset=["Type 1", "Legendary"], inplace=True)

# %% [markdown]
# # Dealing with null values

# %% [markdown]
# - isnull
# - notnull
# - fillna
# - replace
# - dropna

# %%
# select * from excel where Type2 is null
excel[excel["Type 2"].isnull()]

# %%
# select * from excel where Type2 is not null
excel[excel["Type 2"].notnull()]

# %%
# update null values with 'Baha yok' in Type 2 column
excel["Type 2"].fillna("Baha yok", inplace=True)

# %%
# update null values with 'Baha yok' in Type 2 column
excel["Type 2"].replace(np.nan, "Baha yok")
# Out:
# 0        Poison
# 1        Poison
# 2        Poison
# 3        Poison
# 4      Baha yok
#          ...
# 795       Fairy
# 796       Fairy
# 797       Ghost
# 798        Dark
# 799       Water
# Name: Type 2, Length: 800, dtype: object

# %%
# delete all null values rows from df
excel.dropna()

# %% [markdown]
# # Grouping & Aggregating

# %%
excel.groupby("Generation", as_index=False).agg({
    "Name": "count"
})
# Out:
#    Generation  Name
# 0           1   166
# 1           2   106
# 2           3   160
# 3           4   121
# 4           5   165
# 5           6    82

# %%
excel.groupby("Type 1", as_index=False).agg({
    "Defense": "max"
})
# Out:
#       Type 1  Defense
# 0        Bug      230
# 1       Dark      125
# 2     Dragon      130
# 3   Electric      115
# 4      Fairy       95
# 5   Fighting       95
# 6       Fire      140
# 7     Flying       80
# 8      Ghost      145
# 9      Grass      131
# 10    Ground      160
# 11       Ice      184
# 12    Normal      126
# 13    Poison      120
# 14   Psychic      160
# 15      Rock      200
# 16     Steel      230
# 17     Water      180

# %%
excel.groupby(["Type 1", "Legendary"], as_index=False).agg({
    "Attack": "max"
})
# Out:
#       Type 1  Legendary  Attack
# 0        Bug      False     185
# 1       Dark      False     150
# 2       Dark       True     131
# 3     Dragon      False     170
# 4     Dragon       True     180
# 5   Electric      False     123
# 6   Electric       True     115
# 7      Fairy      False     120
# 8      Fairy       True     131
# 9   Fighting      False     145
# 10      Fire      False     160
# 11      Fire       True     130
# 12    Flying      False      70
# 13    Flying       True     115
# 14     Ghost      False     165
# 15     Ghost       True     120
# 16     Grass      False     132
# 17     Grass       True     103
# 18    Ground      False     140
# 19    Ground       True     180
# 20       Ice      False     130
# 21       Ice       True      85
# 22    Normal      False     160
# 23    Normal       True     160
# 24    Poison      False     106
# 25   Psychic      False     165
# 26   Psychic       True     190
# 27      Rock      False     165
# ...

# %% [markdown]
# # Combining Data
#
#     - merge()      -> for combining data on common columns or indices
#     - join()       -> for combining data on a key column or an index
#     - concat()     -> for combining DataFrames across rows or columns

# %%
from IPython.display import Image
Image(filename='diagram.jpg')

# %% [markdown]
# ## concat()

# %%
# Preparing datas
left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


right = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

yanwar = pd.DataFrame(
    {
        "satyshSenesi": ["2/1/2023", "2/1/2023"],
        "satyjyID": [1, 1],
        "harytID": [2, 1],
        "naceHaryt": [2, 3],
        "totalBahasy": [26, 21]
    },
    index=[0, 1],
)


fewral = pd.DataFrame(
    {
        "satyshSenesi": ["3/2/2023", "3/2/2023", "3/2/2023"],
        "satyjyID": [1, 1, 2],
        "harytID": [2, 1, 2],
        "naceHaryt": [2, 3, 2],
        "totalBahasy": [26, 21, 26],
        "peydasy": [0, 0, 0]
    },
    index=[0, 1, 2],
)

haryt = pd.DataFrame(
    {
        "harytIDs": [1, 2, 3],
        "harytAdy": ["futbol top", 'Tarelka', "Dell Computer"],
        "ozBahasy": [5, 10, 300],
        "satyshBahasy": [7, 13, 350],
        "harytKategoryasy": ["sport", "kuhnya", "tehnologiya"]
    },
    index=[0, 1, 2],
)

# %%
# union = pd.concat([yanwar, fewral], keys=["yanwar", "fewral"])
# union.loc['yanwar']
union = pd.concat([yanwar, fewral], ignore_index=True)

# %%
horz = pd.concat([union, haryt], axis=1, join="inner")

# %% [markdown]
# ## merge()
#     pd.merge(
#         left,
#         right,
#         how="inner",
#         on=None,
#         left_on=None,
#         right_on=None,
#         left_index=False,
#         right_index=False,
#         sort=True,
#         suffixes=("_x", "_y"),
#         indicator=True,
#         validate=None
#     )
#
#     validate - one_to_one / one_to_many / many_to_one / many_to_many

# %%
joined = pd.merge(union, haryt, left_on="harytID", right_on="harytIDs", how="inner", sort=True, indicator="Indicator")

# %% [markdown]
# # Hierarchical Indexing (MultiIndex)
#     - from_tuples()
#     - from_arrays()
#     - from_product()
#     - from_frame()

# %% [markdown]
# ## from_tuples()

# %%
tuples = [
    (1, 'Python'),
    (1, 'SQL'),
    (2, 'Java'),
    (2, 'JavaScript'),
    (3, 'Csharp'),
]

data = {
    'Col1': [10, 20, 30, 40, 50],
    'Col2': [60, 70, 80, 90, 100]
}

mi = pd.MultiIndex.from_tuples(tuples, names=['Top', 'PLang'])

df = pd.DataFrame(data, index=mi)

# %% [markdown]
# ## from_arrays()

# %%
import numpy as np

arrays = [
    np.array(["A", "A", "B", "B", "C", "C", "D", "D"]),
    np.array(["one", "two", "one", "two", "one", "two", "one", "two"]),
    np.array(["1", "1", "2", "2", "3", "3", "4", "4"]),
]

data = {
    'col1': [1, 2, 3, 4, 5, 6, 7, 8], 
    'col2': [9, 10, 11, 12, 13, 14, 15, 16]
}

mi = pd.MultiIndex.from_arrays(arrays, names=['First', 'Second', 'Third'])

df_arrays = pd.DataFrame(data, index=mi)

# %% [markdown]
# ## from_product()

# %%
products = [
    ["A", "B", "C", "D"], 
    ["one", "two"]
]


data = {
    'col1': [1, 2, 3, 4, 5, 6, 7, 8], 
    'col2': [9, 10, 11, 12, 13, 14, 15, 16]
}

mi = pd.MultiIndex.from_product(products, names=['First', 'Second'])

df = pd.DataFrame(data, index=mi)

# %% [markdown]
# ## from_frame()

# %%
df = pd.DataFrame(
    {
        'First': ['A', 'A', 'B', 'B'],
        'Second': ['one', 'two', 'one', 'two']
    }
)

data = {'col1': [1, 2, 3, 4], 'col2': [5, 6, 7, 8]}

mi = pd.MultiIndex.from_frame(df)

df = pd.DataFrame(data, index=mi)

# %% [markdown]
# ## set_index()

# %%
df = pd.DataFrame({
    'col1': ['A', 'A', 'B', 'B'],
    'col2': ['one', 'two', 'one', 'two'],
    'col3': [1, 2, 3, 4],
    'col4': [5, 6, 7, 8]
})

df.set_index(['col1', 'col2'], inplace=True)

# %% [markdown]
# ## Extra (MultiIndex)

# %%
# sorting by index
df_arrays.sort_index(level='Third', ascending=True)

# %%
# filtering by index
df_arrays.loc['B']
df_arrays.loc['B', 'two']
df_arrays.loc[('A', 'two'): ('B', 'one')]

# %%
# renaming indexes
df_arrays.index.set_names(['First', 'Sanlar', 'Digitler'], inplace=True)

# %%
# aggregate by index
df_arrays.groupby(level='First')[['col1', 'col2']].sum()

# %%
# get index values
df.index.get_level_values(0)
df.index.get_level_values('First')

# %% [markdown]
# # Data Reshaping

# %% [markdown]
# ## Unpivot
#
#     pd.melt(
#         df,
#         id_vars='col',
#         value_vars=[],
#         value_name='',
#         var_name='',
#     )

# %%
df = pd.DataFrame(
    {
        'team': ['A', 'B', 'C', 'D', 'E'],        
        'points': [18, 22, 19, 14, 14],
        'assists': [5, 7, 7, 9, 12],
        'rebounds': [11, 8, 10, 6, 6]
    }
)

# %%
df_unpivot = pd.melt(df, id_vars='team', value_vars=['points', 'assists', 'rebounds'], var_name='Metric', value_name='Bahalar')

# %% [markdown]
# ## pivot
#
#     df.pivot(index="col", columns="", values="")

# %%
df_pivot = df_unpivot.pivot(index='team', columns='Metric', values='Bahalar')

# %% [markdown]
# ## pivot_table()
#
#     # pd.pivot_table(df, values='col', index=['col'], columns='col', aggfunc=np.sum)
#
#     List of np agg funtions
#     - np.sum
#     - np.min
#     - np.max
#     - np.count
#     - np.mean
#     - np.median
#     - np.std
#     - np.var

# %%
df = pd.DataFrame(
    {
        'Product': ['A', 'A', 'B', 'B', 'C', 'C', 'A'],
        'Region': ['North', 'South', 'North', 'South', 'North', 'South', 'South'],
        'Sales': [100, 200, 150, 50, 75, 125, 100],
        'Expenses': [30, 35, 33, 7, 11, 15, 30]
    }
)

# %%
# df.pivot(index='Product', columns='Region', values='Sales')
df_pvt_table = df.pivot_table(index='Product', columns='Region', values='Sales', aggfunc=np.sum)
# Out:
# 3.95 ms ± 119 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Table Visualization

# %%
import pandas as pd
import numpy as np

# create a sample dataframe
data = [
    [10, 15, 13, 17], 
    [21, 10, 14, 22]
]

index = pd.Index(['Group A', 'Group B'], name='Group')
columns = pd.MultiIndex.from_product([['Gold Points', 'Silver Points'], ['January', 'February']],
                                      names=['Type', 'Month'])
df = pd.DataFrame(data, index=index, columns=columns)

# create a table visualization with conditional formatting
def format_table(val):
    if val < 15:
        textcolor = "red"
        bgcolor = "pink"
        fontstyle = "italic"
    else:
        textcolor = "white"
        bgcolor = "teal"
        fontstyle = "bold"
    
    return f"background-color: {bgcolor}; color: {textcolor}; font-style: {fontstyle};"

# apply formatting funtion
table = df.style.applymap(format_table)
table.set_table_styles(
    [
    {'selector': 'th:hover', 'props': [('background-color', 'blue'), ('color', 'white')]},
    {'selector': 'td:hover', 'props': [('background-color', 'orange'), ('color', 'blue')]},
    {'selector': 'tr:hover', 'props': [('background-color', 'red'), ('color', 'white')]},
    ]
)

# display the table

table
# Out:
# <style type="text/css">
# #T_768a7 th:hover {
#   background-color: blue;
#   color: white;
# }
# #T_768a7 td:hover {
#   background-color: orange;
#   color: blue;
# }
# #T_768a7 tr:hover {
#   background-color: red;
#   color: white;
# }
# #T_768a7_row0_col0, #T_768a7_row0_col2, #T_768a7_row1_col1, #T_768a7_row1_col2 {
#   background-color: pink;
#   color: red;
#   font-style: italic;
# }
# #T_768a7_row0_col1, #T_768a7_row0_col3, #T_768a7_row1_col0, #T_768a7_row1_col3 {
#   background-color: teal;
#   color: white;
#   font-style: bold;
# }
# </style>
# <table id="T_768a7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Type</th>
#       <th id="T_768a7_level0_col0" class="col_heading level0 col0" colspan="2">Gold Points</th>
#       <th id="T_768a7_level0_col2" class="col_heading level0 col2" colspan="2">Silver Points</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Month</th>
# ...

# %% [markdown]
# # Chart Visualization

# %% [raw]
# - bar or barh     for bar plots
# - hist            for histogram
# - box             for boxplot
# - kde or density  for density plots
# - area            for area plots
# - scatter         for scatter plots
# - hexbin          for hexagonal bin plots
# - pie             for pie plots

# %% [markdown]
# ## Line Chart

# %% [raw]
# A line chart is a useful to show trends and changes over time.
# It is a common type of chart used in finance, economics, and other areas to show how a particular variable changes over time.
#
# For example, a line chart can be used to show how the sales of a product have changed over the past year,
# or how the temperature in a city changes over the course of a day.
#
# It can also be used to show the trend of the stock market or the number of website visitors over time.

# %%
import pandas as pd

# create a sample dataframe
data = {
    'yearT': [2015, 2016, 2017, 2018, 2019],
    'sales': [100, 150, 130, 250, 300]
}
df = pd.DataFrame(data)

# plot the data
df.plot(x='yearT', y='sales', kind='line', title='Sales over time')
# Out:
# <AxesSubplot:title={'center':'Sales over time'}, xlabel='yearT'>

# %% [markdown]
# ## Area Chart

# %% [raw]
# Area charts are similar to line charts, but instead of just plotting lines, the area between the x-axis and the line is filled with color.
# The area chart is useful when comparing two or more quantities or categories, and we want to see the changes in proportion over time or across categories.
#
# For example, an area chart can be used to display the total sales of multiple products over time.
# The area chart will allow us to easily see which product has the highest total sales, and how the sales of each product change over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create example data
data = {'Date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05'],
        'Product A': [10, 15, 20, 18, 24],
        'Product B': [5, 13, 17, 24, 22],
        'Product C': [15, 23, 25, 30, 27]}

# create DataFrame
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# define custom colors
colors = {'Product A': 'red', 'Product B': 'blue', 'Product C': 'green'}

# plot the data
df.plot(kind='area', stacked=False, color=colors)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Scatter Plot

# %% [raw]
# Scatter Plot can help to identify the relationship and pattern between the two variables, such as
# - whether they are positively or negatively correlated,
# - whether there are any outliers or clusters, and
# - whether there is any linear or nonlinear relationship.
#
# Scatter plots are often used in data analysis, scientific research, and data visualization to identify trends, patterns, and anomalies in the data.

# %%
import pandas as pd
import numpy as np

# Create a sample dataframe
np.random.seed(123)
data = {
    'Math': np.random.randint(1, 101, 50),
    'English': np.random.randint(1, 101, 50),
    'Science': np.random.randint(1, 101, 50)
}
df = pd.DataFrame(data)

# Create the scatter plot
colors = {'Math': 'red', 'Science': 'blue', 'English': 'green'}
df.plot(kind='scatter', x='Math', y='Science', c='English', colormap='viridis', alpha=0.5, title='Student Exam Scores', s=150)
# Out:
# <AxesSubplot:title={'center':'Student Exam Scores'}, xlabel='Math', ylabel='Science'>

# %% [markdown]
# ## Bar Chart

# %% [raw]
# Bar Chart is commonly used to show comparisons among categories of data.

# %%
# create sample data
data = {
    'Language': ['Python', 'Java', 'C++', 'Javascript', 'Ruby'],
    'Users': [400, 300, 200, 100, 50]
}
df = pd.DataFrame(data)

# plot bar chart with custom colors
colors = ['red', 'orange', 'yellow', 'green', 'blue']
ax = df.plot(kind='bar', x='Language', y='Users', title='Users with Programming Languages', color=colors, legend=False)

# Display values
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.1, p.get_height() + 0.5))

# %%
import pandas as pd

# create sample data
data = {'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
        'Population': [8398748, 3990456, 2705994, 2325502, 1660272]}

# create DataFrame
df = pd.DataFrame(data)

# plot horizontal bar chart
ax = df.plot.barh(x='City', y='Population', color='teal', legend=None)

# Display values
for i, v in enumerate(df['Population']):
    ax.text(v + 3, i, str(v), color='blue', fontweight='bold')

# %% [markdown]
# ## Pie Chart

# %% [raw]
# Pie charts are useful when the data is not too complex, and we want to quickly understand the relative sizes of different categories.
# They are commonly used in business, marketing, and finance to analyze data and make decisions based on the insights gained from the chart.

# %%
import pandas as pd

# Create a sample dataframe
data = {'Chykdajylar': [650, 470, 210, 120, 500]}
index = ['Kwartira', 'Iyim Icgi', 'Yol Pul', 'Snack', 'Geyim Gejim']
df = pd.DataFrame(data=data, index=index)

# Create a pie chart
pie = df.plot(kind='pie', y='Chykdajylar', legend=False, autopct='%1.1f%%', startangle=90)

# %% [markdown]
# # Pandas Profiling

# %%
from pandas_profiling import ProfileReport
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('files/timesData.csv')

# %%
profile = ProfileReport(df, title='Time Data File Profiling')

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-22 14:08:30.392662&quot;&gt;&lt;title&gt;Time Data File Profiling&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file('Time Data Profiling.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
